# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install rdkit
# !pip install keras-tuner --upgrade
# Out:
# Collecting rdkit
#   Downloading rdkit-2023.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.7/29.7 MB 52.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from rdkit) (1.23.5)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from rdkit) (9.4.0)
# Installing collected packages: rdkit
# Successfully installed rdkit-2023.3.3
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
import pandas as pd
import numpy as np
import pickle
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import Descriptors
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from rdkit.Chem.Draw import rdMolDraw2D
import kerastuner as kt
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow.keras.models import Sequential, save_model, load_model
from tensorflow.keras.optimizers import Adam
from tensorflow import keras
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D, Dense, Flatten, Activation, ZeroPadding2D
from tensorflow.keras.layers import LSTM, Embedding, Bidirectional, TimeDistributed, Reshape, Dropout
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.preprocessing.sequence import pad_sequences
import time
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split
import random
from numpy.random import seed
import tensorflow
from keras.layers import Input, Dense
from keras.models import Model
from keras.layers import Concatenate
import argparse
# Out:
# <ipython-input-3-81cbe4447c6e>:11: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt

# %%
#read in the reference data
DF = pickle.load(open("drive/My Drive/Copolymer-main/Copolymer-main/datasets/Copolymer_Dataset_3.pickle","rb"))

#fingperints featurization
fp_1 = DF['SMILES_1_mol'].dropna().apply(lambda m: AllChem.GetMorganFingerprint(m, radius=3))
fp_1_n = fp_1.apply(lambda m: m.GetNonzeroElements())

fp_2 = DF['SMILES_2_mol'].dropna().apply(lambda m: AllChem.GetMorganFingerprint(m, radius=3))
fp_2_n = fp_2.apply(lambda m: m.GetNonzeroElements())

#Recognize all n substructures found in the datasets

HashCode = []
for i in fp_1_n:
    for j in i.keys():
        HashCode.append(j)

for i in fp_2_n:
    for j in i.keys():
        HashCode.append(j)

unique_set = set(HashCode)
unique_list = list(unique_set)

Corr_df = pd.DataFrame(unique_list).reset_index()

#Construct feature matrix
MY_finger = []
for polymer in fp_1_n:
    my_finger = [0] * len(unique_list)
    for key in polymer.keys():
        index = Corr_df[Corr_df[0] == key]['index'].values[0]
        my_finger[index] = polymer[key]
    MY_finger.append(my_finger)

for polymer in fp_2_n:
    my_finger = [0] * len(unique_list)
    for key in polymer.keys():
        index = Corr_df[Corr_df[0] == key]['index'].values[0]
        my_finger[index] = polymer[key]
    MY_finger.append(my_finger)

MY_finger_dataset = pd.DataFrame(MY_finger)

Zero_Sum = (MY_finger_dataset == 0).astype(int).sum()
NumberOfZero = 12800
X_1 = MY_finger_dataset[Zero_Sum[Zero_Sum < NumberOfZero].index].iloc[:131]
X_2 = MY_finger_dataset[Zero_Sum[Zero_Sum < NumberOfZero].index].iloc[131:]

# %%
def train(args):

    #read in the reference data
    DF = pickle.load(open("drive/My Drive/Copolymer-main/Copolymer-main/datasets/Copolymer_Dataset_3.pickle","rb"))

    #fingperints featurization
    fp_1 = DF['SMILES_1_mol'].dropna().apply(lambda m: AllChem.GetMorganFingerprint(m, radius=3))
    fp_1_n = fp_1.apply(lambda m: m.GetNonzeroElements())

    fp_2 = DF['SMILES_2_mol'].dropna().apply(lambda m: AllChem.GetMorganFingerprint(m, radius=3))
    fp_2_n = fp_2.apply(lambda m: m.GetNonzeroElements())

    #Recognize all n substructures found in the datasets

    HashCode = []
    for i in fp_1_n:
        for j in i.keys():
            HashCode.append(j)

    for i in fp_2_n:
        for j in i.keys():
            HashCode.append(j)

    unique_set = set(HashCode)
    unique_list = list(unique_set)

    Corr_df = pd.DataFrame(unique_list).reset_index()

    #Construct feature matrix
    MY_finger = []
    for polymer in fp_1_n:
        my_finger = [0] * len(unique_list)
        for key in polymer.keys():
            index = Corr_df[Corr_df[0] == key]['index'].values[0]
            my_finger[index] = polymer[key]
        MY_finger.append(my_finger)

    for polymer in fp_2_n:
        my_finger = [0] * len(unique_list)
        for key in polymer.keys():
            index = Corr_df[Corr_df[0] == key]['index'].values[0]
            my_finger[index] = polymer[key]
        MY_finger.append(my_finger)

    MY_finger_dataset = pd.DataFrame(MY_finger)

    Zero_Sum = (MY_finger_dataset == 0).astype(int).sum()
    NumberOfZero = 12800
    X_1 = MY_finger_dataset[Zero_Sum[Zero_Sum < NumberOfZero].index].iloc[:131]
    X_2 = MY_finger_dataset[Zero_Sum[Zero_Sum < NumberOfZero].index].iloc[131:]

# %%
# CNN model
#if args.model == 'CNN':
# input for CNN
DF['Ratio_1'] = [int(x) for x in DF['Mon. ratio']]
DF['Ratio_2'] = [100 - int(x) for x in DF['Mon. ratio']]

Mix_X_100Block = []
for i in range(len(DF)):
    if DF['Random/\nBlock'].iloc[i] == 'B':
        Sequency_X = []
        for j in range(int(DF['Ratio_1'].iloc[i])):
            Sequency_X.append((X_1.iloc[i].values))
        for j in range(int(DF['Ratio_2'].iloc[i])):
            Sequency_X.append((X_2.iloc[i].values))
    else:
        random.seed(10)
        X1_random_position = random.sample(range(0, 100), int(DF['Ratio_1'].iloc[i]))
        Sequency_X = [0 for a in range(100)]
        for j in range(100):
            if j in X1_random_position:
                Sequency_X[j] = list(X_1.iloc[i].values)
            else:
                Sequency_X[j] = list(X_2.iloc[i].values)
    Mix_X_100Block.append(Sequency_X)

Mix_X_100Block = np.array(Mix_X_100Block)
Mix_X_100Block = Mix_X_100Block.reshape((131, 100, 125, 1))

# data split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(Mix_X_100Block, DF['Tg_avg'], test_size=0.2, random_state=42)

# model setup using the optimized architecture
model = Sequential()
model.add(Conv2D(8, (10, 10), activation='relu', input_shape=(100, 125, 1)))
model.add(Conv2D(8, (4, 4), activation='relu'))
model.add(Conv2D(8, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(1))
optimizer=keras.optimizers.Adam(lr=0.005)
model.compile(optimizer=optimizer, loss='mean_absolute_error')
model.fit(x=X_train,y=y_train,epochs=200,
                batch_size=64,
                validation_split=0.2)

filepath = 'PK_CNN.model'
save_model(model, filepath, save_format='h5')

# model evaluation
y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)
print("model performance")
print("Train set R^2: %.2f" % r2_score(y_train, y_pred_train))
print("Train MAE score: %.2f" % mean_absolute_error(y_train, y_pred_train))
print("Train RMSE score: %.2f" % np.sqrt(mean_squared_error(y_train, y_pred_train)))
print("Test set R^2: %.2f" % r2_score(y_test, y_pred_test))
print("Test MAE score: %.2f" % mean_absolute_error(y_test, y_pred_test))
print("Test RMSE score: %.2f" % np.sqrt(mean_squared_error(y_test, y_pred_test)))

# %%
# Fusion model
#if args.model == 'Fusion':
# input for Fusion
Mix_X = []
for i in range(len(DF)):
    Mix_X.append(X_1.iloc[i].values * DF['Ratio_1'].iloc[i] + \
                  X_2.iloc[i].values * DF['Ratio_2'].iloc[i])
Mix_X = np.array(Mix_X)

Mix_X_100Block = []
for i in range(len(DF)):
    if DF['Random/\nBlock'].iloc[i] == 'B':
        Sequency_X = []
        for j in range(int(DF['Ratio_1'].iloc[i])):
            Sequency_X.append(1)
        for j in range(int(DF['Ratio_2'].iloc[i])):
            Sequency_X.append(0)
    else:
        random.seed(10)
        X1_random_position = random.sample(range(0, 100), int(DF['Ratio_1'].iloc[i]))
        Sequency_X = [0 for a in range(100)]
        for j in range(100):
            if j in X1_random_position:
                Sequency_X[j] = 1
            else:
                Sequency_X[j] = 0
    Mix_X_100Block.append(Sequency_X)

Mix_X_100Block = np.array(Mix_X_100Block)
Mix_X_100Block = Mix_X_100Block.reshape((131, 100, 1))

LSTMunits = 20 # hyperprameter for LSTM
# define two sets of inputs
inputA = Input(shape=(100,1))
inputB = Input(shape=(125))

# model setup using the optimized architecture
# the first branch operates on the first input
RNNmodel = Sequential()
RNNmodel.add(Bidirectional(LSTM(LSTMunits, return_sequences=True), input_shape=(100,1)))
RNNmodel.add(Bidirectional(LSTM(LSTMunits, return_sequences=True)))
RNNmodel.add(TimeDistributed(Dense(int(LSTMunits/2), activation="relu")))
RNNmodel.add(Reshape((int(LSTMunits/2*100),)))

# the second branch opreates on the second input
y = Dense(8, activation="relu")(inputB)
y = Dense(8, activation="relu")(y)
y = Model(inputs=inputB, outputs=y)

# fuse two branches
combined = Concatenate()([RNNmodel.output, y.output])
z = Dense(8, activation="relu")(combined)
z = Dense(1, activation="linear")(z)
model = Model(inputs=[RNNmodel.input, y.input], outputs=z)

# data split into train/test sets
xtrain_A, xtest_A, ytrain_A, ytest_A=train_test_split(Mix_X_100Block, DF['Tg_avg'], test_size=0.20, random_state=200)
xtrain_B, xtest_B, ytrain_B, ytest_B=train_test_split(Mix_X, DF['Tg_avg'], test_size=0.20, random_state=200)

optimizer=keras.optimizers.Adam(lr=0.001)
model.compile(optimizer=optimizer, loss='mean_absolute_error')
model.fit(x=[xtrain_A, xtrain_B], y=ytrain_B,epochs=500,
                batch_size=32,
                validation_split=0.2)

filepath = 'PK_Fusion.model'
save_model(model, filepath, save_format='h5')

# model evaluation
print("model performance")
ytrain = ytrain_B
ytest = ytest_B
y_pred_train = model.predict([xtrain_A, xtrain_B])
print("Train set R^2: ", r2_score(ytrain, y_pred_train))
print("Train MAE score: %.2f" % mean_absolute_error(ytrain, y_pred_train))
print("Train RMSE score: %.2f" % np.sqrt(mean_squared_error(ytrain, y_pred_train)))
y_pred_test = model.predict([xtest_A, xtest_B])
print("Test set R^2: ", r2_score(ytest, y_pred_test))
print("Test MAE score: %.2f" % mean_absolute_error(ytest, y_pred_test))
print("Test RMSE score: %.2f" % np.sqrt(mean_squared_error(ytest, y_pred_test)))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Epoch 1
# Epoch 480/500
# 3/3 [==============================] - 0s 141ms/step - loss: 1.9340 - val_loss: 5.0492
# Epoch 481/500
# 3/3 [==============================] - 0s 136ms/step - loss: 1.9105 - val_loss: 4.9083
# Epoch 482/500
# 3/3 [==============================] - 0s 153ms/step - loss: 1.9066 - val_loss: 4.9022
# Epoch 483/500
# 3/3 [==============================] - 0s 160ms/step - loss: 1.9068 - val_loss: 4.8696
# Epoch 484/500
# 3/3 [==============================] - 0s 145ms/step - loss: 2.0307 - val_loss: 4.9874
# Epoch 485/500
# 3/3 [==============================] - 0s 137ms/step - loss: 1.9828 - val_loss: 5.1430
# Epoch 486/500
# 3/3 [==============================] - 0s 156ms/step - loss: 2.0586 - val_loss: 4.8684
# Epoch 487/500
# 3/3 [==============================] - 0s 139ms/step - loss: 1.9821 - val_loss: 4.8899
# Epoch 488/500
# 3/3 [==============================] - 1s 231ms/step - loss: 1.9522 - val_loss: 4.9116
# Epoch 489/500
# 3/3 [==============================] - 1s 247ms/step - loss: 1.9165 - val_loss: 5.0558
# Epoch 490/500
# 3/3 [==============================] - 1s 290ms/step - loss: 1.9788 - val_loss: 5.1757
# Epoch 491/500
# 3/3 [==============================] - 1s 293ms/step - loss: 2.0307 - val_loss: 5.0528
# Epoch 492/500
# 3/3 [==============================] - 1s 285ms/step - loss: 1.9408 - val_loss: 4.8530
# Epoch 493/500
# 3/3 [==============================] - 1s 204ms/step - loss: 1.9557 - val_loss: 4.9236
# Epoch 494/500
# 3/3 [==============================] - 0s 176ms/step - loss: 1.8645 - val_loss: 5.0404
# Epoch 495/500
# 3/3 [==============================] - 0s 155ms/step - loss: 1.8942 - val_loss: 5.0782
# Epoch 496/500
# 3/3 [==============================] - 0s 151ms/step - loss: 1.8815 - val_loss: 5.0792
# Epoch 497/500
# 3/3 [==============================] - 0s 168ms/step - loss: 1.8961 - val_loss: 4.9283
# Epoch 498/500
# 3/3 [==============================] - 0s 172ms/step - loss: 1.8812 - val_loss: 4.8971
# Epoch 499/500
# 3/3 [==============================] - 0s 157ms/step - loss: 1.8990 - val_loss: 4.9971
# Epoch 500/500
# 3/3 [==============================] - 0s 169ms/step - loss: 1.8616 - val_loss: 4.9507
# <ipython-input-6-ed492653e589>:67: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   save_model(model, filepath, save_format='h5')
# model performance
# 4/4 [==============================] - 2s 23ms/step
# Train set R^2:  0.9158323944874144
# Train MAE score: 2.48
# Train RMSE score: 4.35
# 1/1 [==============================] - 0s 39ms/step
# Test set R^2:  0.9353288398260508
# Test MAE score: 2.72
# Test RMSE score: 3.52

# %%
# FFNN model
#if args.model == 'FFNN':

# data split into train/test sets
x_train, x_test, y_train, y_test = train_test_split(Mix_X, DF['Tg_avg'], test_size=0.2, random_state=11)
# model setup using the optimized architecture
model = keras.models.Sequential()
model.add(Dense(units = 24, input_dim = x_train.shape[1],activation='relu'))
model.add(Dense(units = 64, activation='relu'))
model.add(Dense(units = 1))
model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.001),
              loss="mean_squared_error")
model.fit(x_train, y_train, epochs = 1000, batch_size = 128,
          validation_split=0.2)

filepath = 'PK_FFNN.model'
save_model(model, filepath, save_format='h5')

# model evaluation
print("model performance")
y_pred_train = model.predict((x_train))
print("Train set R^2: %.2f" % r2_score(y_train, y_pred_train))
print("Train MAE score: %.2f" % mean_absolute_error(y_train, y_pred_train))
print("Train RMSE score: %.2f" % np.sqrt(mean_squared_error(y_train, y_pred_train)))
y_pred_test = model.predict((x_test))
print("Test set R^2: %.2f" % r2_score(y_test, y_pred_test))
print("Test MAE score: %.2f" % mean_absolute_error(y_test, y_pred_test))
print("Test RMSE score: %.2f" % np.sqrt(mean_squared_error(y_test, y_pred_test)))
# Out:
# Epoch 1/1000
# 1/1 [==============================] - 1s 786ms/step - loss: 558.3829 - val_loss: 349.7925
# Epoch 2/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 401.2668 - val_loss: 229.4840
# Epoch 3/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 280.9393 - val_loss: 153.3466
# Epoch 4/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 193.2100 - val_loss: 105.4212
# Epoch 5/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 132.4695 - val_loss: 78.0411
# Epoch 6/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 93.9301 - val_loss: 64.6970
# Epoch 7/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 71.6011 - val_loss: 60.3612
# Epoch 8/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 60.4473 - val_loss: 60.4699
# Epoch 9/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 55.7647 - val_loss: 62.2073
# Epoch 10/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 54.1108 - val_loss: 64.5242
# Epoch 11/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 53.1756 - val_loss: 67.5211
# Epoch 12/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 51.7695 - val_loss: 71.4617
# Epoch 13/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 49.5196 - val_loss: 76.4494
# Epoch 14/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 46.6872 - val_loss: 79.6874
# Epoch 15/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 43.7267 - val_loss: 82.1371
# Epoch 16/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 40.9327 - val_loss: 83.3757
# Epoch 17/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 38.9714 - val_loss: 82.6285
# Epoch 18/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 37.3076 - val_loss: 79.6179
# Epoch 19/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 35.5290 - val_loss: 75.1112
# Epoch 20/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 33.3630 - val_loss: 68.2805
# Epoch 21/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 31.0186 - val_loss: 60.4827
# Epoch 22/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 28.5287 - val_loss: 52.7725
# Epoch 23/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 26.4447 - val_loss: 46.0589
# Epoch 24/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 25.0976 - val_loss: 41.0659
# Epoch 25/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 24.5712 - val_loss: 37.8252
# Epoch 26/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 24.6558 - val_loss: 36.0661
# Epoch 27/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 24.8726 - val_loss: 35.2368
# Epoch 28/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 24.9563 - val_loss: 34.9463
# Epoch 29/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 24.7789 - val_loss: 34.9395
# Epoch 30/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 24.4052 - val_loss: 35.1696
# Epoch 31/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 23.9437 - val_loss: 35.5465
# Epoch 32/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 23.4654 - val_loss: 35.9205
# Epoch 33/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 22.8846 - val_loss: 36.3121
# Epoch 34/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 22.2091 - val_loss: 36.7418
# Epoch 35/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 21.4703 - val_loss: 37.3835
# Epoch 36/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 20.8249 - val_loss: 38.1963
# Epoch 37/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 20.2765 - val_loss: 39.1319
# Epoch 38/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 19.8366 - val_loss: 40.1197
# Epoch 39/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 19.5482 - val_loss: 41.1442
# Epoch 40/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 19.4301 - val_loss: 42.1551
# Epoch 41/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 19.4253 - val_loss: 43.0242
# Epoch 42/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 19.4601 - val_loss: 43.6745
# Epoch 43/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 19.4844 - val_loss: 44.0293
# Epoch 44/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 19.4492 - val_loss: 44.0614
# Epoch 45/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 19.3148 - val_loss: 43.7605
# Epoch 46/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 19.0904 - val_loss: 43.1829
# Epoch 47/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 18.7891 - val_loss: 42.4167
# Epoch 48/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 18.4585 - val_loss: 41.5700
# Epoch 49/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 18.1282 - val_loss: 40.6856
# Epoch 50/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 17.8613 - val_loss: 39.8656
# Epoch 51/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 17.6569 - val_loss: 39.1814
# Epoch 52/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 17.5129 - val_loss: 38.6027
# Epoch 53/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 17.4270 - val_loss: 38.1810
# Epoch 54/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 17.3625 - val_loss: 37.8676
# Epoch 55/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 17.2921 - val_loss: 37.6923
# Epoch 56/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 17.2040 - val_loss: 37.6966
# Epoch 57/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 17.1029 - val_loss: 37.9790
# Epoch 58/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 17.0084 - val_loss: 38.4292
# Epoch 59/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 16.9090 - val_loss: 38.9926
# Epoch 60/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 16.7957 - val_loss: 39.6407
# Epoch 61/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 16.6848 - val_loss: 40.3148
# Epoch 62/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 16.5796 - val_loss: 41.0196
# Epoch 63/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 16.5061 - val_loss: 41.7221
# Epoch 64/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 16.4696 - val_loss: 42.3509
# Epoch 65/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 16.4441 - val_loss: 42.8320
# Epoch 66/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 16.4146 - val_loss: 43.1075
# Epoch 67/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 16.3717 - val_loss: 43.2396
# Epoch 68/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 16.3330 - val_loss: 43.2718
# Epoch 69/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 16.3009 - val_loss: 43.2243
# Epoch 70/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 16.2715 - val_loss: 43.0885
# Epoch 71/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 16.2383 - val_loss: 42.9094
# Epoch 72/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 16.1982 - val_loss: 42.7323
# Epoch 73/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 16.1646 - val_loss: 42.5964
# Epoch 74/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 16.1443 - val_loss: 42.5109
# Epoch 75/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 16.1226 - val_loss: 42.4688
# Epoch 76/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 16.0948 - val_loss: 42.4556
# Epoch 77/1000
# 1/1 [==============================] - 0s 71ms/step - loss: 16.0564 - val_loss: 42.4936
# Epoch 78/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 16.0132 - val_loss: 42.5847
# Epoch 79/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 15.9739 - val_loss: 42.7274
# Epoch 80/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 15.9410 - val_loss: 42.9162
# Epoch 81/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 15.9086 - val_loss: 43.1295
# Epoch 82/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 15.8738 - val_loss: 43.3576
# Epoch 83/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 15.8422 - val_loss: 43.5659
# Epoch 84/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 15.8147 - val_loss: 43.7381
# Epoch 85/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 15.7867 - val_loss: 43.8725
# Epoch 86/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 15.7574 - val_loss: 43.9502
# Epoch 87/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 15.7260 - val_loss: 43.9997
# Epoch 88/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 15.6944 - val_loss: 44.0188
# Epoch 89/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 15.6628 - val_loss: 44.0249
# Epoch 90/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 15.6336 - val_loss: 43.9974
# Epoch 91/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 15.6047 - val_loss: 43.9456
# Epoch 92/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 15.5763 - val_loss: 43.8872
# Epoch 93/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 15.5493 - val_loss: 43.8515
# Epoch 94/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 15.5224 - val_loss: 43.8291
# Epoch 95/1000
# 1/1 [==============================] - 0s 74ms/step - loss: 15.4938 - val_loss: 43.8216
# Epoch 96/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 15.4651 - val_loss: 43.8584
# Epoch 97/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 15.4397 - val_loss: 43.9713
# Epoch 98/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 15.4138 - val_loss: 44.1173
# Epoch 99/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 15.3849 - val_loss: 44.2675
# Epoch 100/1000
# 1/1 [==============================] - 0s 70ms/step - loss: 15.3545 - val_loss: 44.4073
# Epoch 101/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 15.3300 - val_loss: 44.5436
# Epoch 102/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 15.3048 - val_loss: 44.6808
# Epoch 103/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 15.2744 - val_loss: 44.8213
# Epoch 104/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 15.2525 - val_loss: 44.8950
# Epoch 105/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 15.2382 - val_loss: 44.7808
# Epoch 106/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 15.2073 - val_loss: 44.5430
# Epoch 107/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 15.1766 - val_loss: 44.4058
# Epoch 108/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 15.1612 - val_loss: 44.4002
# Epoch 109/1000
# 1/1 [==============================] - 0s 61ms/step - loss: 15.1384 - val_loss: 44.5320
# Epoch 110/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 15.1143 - val_loss: 44.6645
# Epoch 111/1000
# 1/1 [==============================] - 0s 60ms/step - loss: 15.0947 - val_loss: 44.7495
# Epoch 112/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 15.0739 - val_loss: 44.7932
# Epoch 113/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 15.0517 - val_loss: 44.7500
# Epoch 114/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 15.0259 - val_loss: 44.6261
# Epoch 115/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 15.0031 - val_loss: 44.6035
# Epoch 116/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 14.9807 - val_loss: 44.6934
# Epoch 117/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 14.9591 - val_loss: 44.7111
# Epoch 118/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 14.9391 - val_loss: 44.6603
# Epoch 119/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.9159 - val_loss: 44.5419
# Epoch 120/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.8921 - val_loss: 44.5351
# Epoch 121/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 14.8691 - val_loss: 44.4567
# Epoch 122/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 14.8491 - val_loss: 44.5028
# Epoch 123/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 14.8265 - val_loss: 44.4737
# Epoch 124/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.8040 - val_loss: 44.4073
# Epoch 125/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 14.7806 - val_loss: 44.3429
# Epoch 126/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.7596 - val_loss: 44.4259
# Epoch 127/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 14.7379 - val_loss: 44.4228
# Epoch 128/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 14.7201 - val_loss: 44.3723
# Epoch 129/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.6980 - val_loss: 44.2901
# Epoch 130/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.6836 - val_loss: 44.3537
# Epoch 131/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 14.6570 - val_loss: 44.5597
# Epoch 132/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.6408 - val_loss: 44.6056
# Epoch 133/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 14.6232 - val_loss: 44.4776
# Epoch 134/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 14.6078 - val_loss: 44.2714
# Epoch 135/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.5873 - val_loss: 44.0699
# Epoch 136/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.5574 - val_loss: 43.8928
# Epoch 137/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.5441 - val_loss: 44.1076
# Epoch 138/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.5210 - val_loss: 44.2572
# Epoch 139/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.5060 - val_loss: 44.2866
# Epoch 140/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 14.4886 - val_loss: 44.0838
# Epoch 141/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.4656 - val_loss: 43.8145
# Epoch 142/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.4587 - val_loss: 43.9230
# Epoch 143/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.4346 - val_loss: 44.0929
# Epoch 144/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.4142 - val_loss: 44.1396
# Epoch 145/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.3893 - val_loss: 44.0551
# Epoch 146/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 14.3785 - val_loss: 44.2204
# Epoch 147/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 14.3588 - val_loss: 44.4994
# Epoch 148/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 14.3432 - val_loss: 44.0892
# Epoch 149/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.3155 - val_loss: 44.0044
# Epoch 150/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.2986 - val_loss: 43.9293
# Epoch 151/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.2870 - val_loss: 43.8836
# Epoch 152/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 14.2675 - val_loss: 43.8648
# Epoch 153/1000
# 1/1 [==============================] - 0s 48ms/step - loss: 14.2467 - val_loss: 44.2172
# Epoch 154/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.2265 - val_loss: 44.5672
# Epoch 155/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 14.2268 - val_loss: 44.1829
# Epoch 156/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 14.1984 - val_loss: 44.0259
# Epoch 157/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.1773 - val_loss: 44.0907
# Epoch 158/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.1537 - val_loss: 44.3283
# Epoch 159/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 14.1556 - val_loss: 44.3587
# Epoch 160/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 14.1439 - val_loss: 44.1872
# Epoch 161/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 14.1192 - val_loss: 43.8829
# Epoch 162/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 14.1033 - val_loss: 43.7543
# Epoch 163/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 14.0831 - val_loss: 44.0072
# Epoch 164/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 14.0555 - val_loss: 44.2587
# Epoch 165/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 14.0510 - val_loss: 44.1825
# Epoch 166/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 14.0318 - val_loss: 44.1841
# Epoch 167/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 14.0164 - val_loss: 44.2848
# Epoch 168/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 13.9975 - val_loss: 44.1047
# Epoch 169/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.9806 - val_loss: 44.0686
# Epoch 170/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 13.9578 - val_loss: 44.2098
# Epoch 171/1000
# 1/1 [==============================] - 0s 30ms/step - loss: 13.9562 - val_loss: 44.1258
# Epoch 172/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 13.9422 - val_loss: 43.8372
# Epoch 173/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.9205 - val_loss: 43.6795
# Epoch 174/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.9117 - val_loss: 43.9685
# Epoch 175/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.8787 - val_loss: 44.5172
# Epoch 176/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.8865 - val_loss: 44.6342
# Epoch 177/1000
# 1/1 [==============================] - 0s 31ms/step - loss: 13.8813 - val_loss: 43.9671
# Epoch 178/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 13.8405 - val_loss: 43.6146
# Epoch 179/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 13.8384 - val_loss: 43.7137
# Epoch 180/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.8119 - val_loss: 44.1995
# Epoch 181/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.8150 - val_loss: 44.4332
# Epoch 182/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.8122 - val_loss: 44.2602
# Epoch 183/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.7853 - val_loss: 43.8749
# Epoch 184/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.7607 - val_loss: 43.5021
# Epoch 185/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.7663 - val_loss: 43.4445
# Epoch 186/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.7566 - val_loss: 43.6595
# Epoch 187/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.7330 - val_loss: 44.0934
# Epoch 188/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.7023 - val_loss: 44.5732
# Epoch 189/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.7161 - val_loss: 44.5679
# Epoch 190/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 13.7062 - val_loss: 44.1863
# Epoch 191/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.6764 - val_loss: 43.6636
# Epoch 192/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.6674 - val_loss: 43.6559
# Epoch 193/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.6536 - val_loss: 44.0783
# Epoch 194/1000
# 1/1 [==============================] - 0s 55ms/step - loss: 13.6282 - val_loss: 44.3088
# Epoch 195/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.6194 - val_loss: 44.1343
# Epoch 196/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.6098 - val_loss: 44.1129
# Epoch 197/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.6086 - val_loss: 44.2328
# Epoch 198/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.5932 - val_loss: 44.4380
# Epoch 199/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.5667 - val_loss: 44.6857
# Epoch 200/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 13.5767 - val_loss: 44.4350
# Epoch 201/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 13.5586 - val_loss: 43.9102
# Epoch 202/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.5395 - val_loss: 43.8532
# Epoch 203/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.5290 - val_loss: 44.2097
# Epoch 204/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 13.5154 - val_loss: 44.3122
# Epoch 205/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.5056 - val_loss: 44.0714
# Epoch 206/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.4877 - val_loss: 43.9625
# Epoch 207/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 13.4808 - val_loss: 44.0025
# Epoch 208/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.4654 - val_loss: 44.2313
# Epoch 209/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.4515 - val_loss: 44.1611
# Epoch 210/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.4389 - val_loss: 43.9965
# Epoch 211/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.4353 - val_loss: 44.0743
# Epoch 212/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.4228 - val_loss: 44.3297
# Epoch 213/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.4127 - val_loss: 44.2789
# Epoch 214/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.4002 - val_loss: 44.0345
# Epoch 215/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.3955 - val_loss: 44.0395
# Epoch 216/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.3860 - val_loss: 44.2814
# Epoch 217/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.3675 - val_loss: 44.7030
# Epoch 218/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.3694 - val_loss: 44.6193
# Epoch 219/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.3543 - val_loss: 44.1590
# Epoch 220/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.3472 - val_loss: 43.9707
# Epoch 221/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.3398 - val_loss: 44.0708
# Epoch 222/1000
# 1/1 [==============================] - 0s 52ms/step - loss: 13.3218 - val_loss: 44.3987
# Epoch 223/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.3050 - val_loss: 44.8370
# Epoch 224/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 13.3147 - val_loss: 44.7886
# Epoch 225/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.3009 - val_loss: 44.3161
# Epoch 226/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.2782 - val_loss: 44.0690
# Epoch 227/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.2755 - val_loss: 44.0570
# Epoch 228/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 13.2674 - val_loss: 44.2513
# Epoch 229/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.2494 - val_loss: 44.5959
# Epoch 230/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.2570 - val_loss: 44.5387
# Epoch 231/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.2469 - val_loss: 44.2186
# Epoch 232/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 13.2279 - val_loss: 44.4215
# Epoch 233/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.2105 - val_loss: 44.7102
# Epoch 234/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.2142 - val_loss: 44.5135
# Epoch 235/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.1990 - val_loss: 44.4394
# Epoch 236/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.1916 - val_loss: 44.5253
# Epoch 237/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.1828 - val_loss: 44.7247
# Epoch 238/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.1775 - val_loss: 44.6267
# Epoch 239/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.1629 - val_loss: 44.1547
# Epoch 240/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.1614 - val_loss: 44.2240
# Epoch 241/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.1575 - val_loss: 44.4684
# Epoch 242/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.1449 - val_loss: 44.8514
# Epoch 243/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.1294 - val_loss: 45.1165
# Epoch 244/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 13.1399 - val_loss: 44.7310
# Epoch 245/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 13.1185 - val_loss: 44.0901
# Epoch 246/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 13.1294 - val_loss: 44.0849
# Epoch 247/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 13.1192 - val_loss: 44.6449
# Epoch 248/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 13.0979 - val_loss: 45.3401
# Epoch 249/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.1101 - val_loss: 45.2070
# Epoch 250/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.0927 - val_loss: 44.4582
# Epoch 251/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 13.0871 - val_loss: 44.0299
# Epoch 252/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.0863 - val_loss: 43.9498
# Epoch 253/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.0839 - val_loss: 44.4666
# Epoch 254/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 13.0696 - val_loss: 45.0704
# Epoch 255/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.0535 - val_loss: 45.4338
# Epoch 256/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.0559 - val_loss: 44.9615
# Epoch 257/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 13.0440 - val_loss: 44.6350
# Epoch 258/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.0284 - val_loss: 44.5242
# Epoch 259/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 13.0182 - val_loss: 44.4909
# Epoch 260/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.0204 - val_loss: 44.5967
# Epoch 261/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 13.0076 - val_loss: 44.3312
# Epoch 262/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9989 - val_loss: 44.3207
# Epoch 263/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 13.0043 - val_loss: 44.5423
# Epoch 264/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.9882 - val_loss: 44.9433
# Epoch 265/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 12.9805 - val_loss: 45.3083
# Epoch 266/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9945 - val_loss: 44.9015
# Epoch 267/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.9672 - val_loss: 44.1400
# Epoch 268/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.9798 - val_loss: 44.1211
# Epoch 269/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.9670 - val_loss: 44.7838
# Epoch 270/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.9571 - val_loss: 45.5392
# Epoch 271/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9666 - val_loss: 45.7952
# Epoch 272/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9695 - val_loss: 45.0131
# Epoch 273/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.9406 - val_loss: 44.3048
# Epoch 274/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.9384 - val_loss: 44.0165
# Epoch 275/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.9429 - val_loss: 44.4095
# Epoch 276/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9196 - val_loss: 45.3252
# Epoch 277/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.9354 - val_loss: 45.4404
# Epoch 278/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.9274 - val_loss: 44.8798
# Epoch 279/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 12.9031 - val_loss: 44.3792
# Epoch 280/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 12.9041 - val_loss: 44.1149
# Epoch 281/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 12.8968 - val_loss: 44.1933
# Epoch 282/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.8946 - val_loss: 44.5477
# Epoch 283/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.8830 - val_loss: 45.0145
# Epoch 284/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 12.8697 - val_loss: 45.4193
# Epoch 285/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8844 - val_loss: 45.1721
# Epoch 286/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8706 - val_loss: 44.4533
# Epoch 287/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8704 - val_loss: 44.3529
# Epoch 288/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 12.8666 - val_loss: 44.8165
# Epoch 289/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 12.8544 - val_loss: 45.2755
# Epoch 290/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8478 - val_loss: 45.5875
# Epoch 291/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8493 - val_loss: 45.4867
# Epoch 292/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8455 - val_loss: 44.6057
# Epoch 293/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8289 - val_loss: 44.0420
# Epoch 294/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.8454 - val_loss: 44.2482
# Epoch 295/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 12.8329 - val_loss: 45.0662
# Epoch 296/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8116 - val_loss: 45.8049
# Epoch 297/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.8341 - val_loss: 45.4932
# Epoch 298/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8145 - val_loss: 44.6605
# Epoch 299/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 12.8057 - val_loss: 44.0937
# Epoch 300/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.8136 - val_loss: 44.2540
# Epoch 301/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.8110 - val_loss: 45.0134
# Epoch 302/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.7963 - val_loss: 45.6392
# Epoch 303/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 12.7914 - val_loss: 45.8214
# Epoch 304/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.7939 - val_loss: 45.6023
# Epoch 305/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.7771 - val_loss: 45.2991
# Epoch 306/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.7617 - val_loss: 44.9997
# Epoch 307/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 12.7622 - val_loss: 44.7541
# Epoch 308/1000
# 1/1 [==============================] - 0s 35ms/step - loss: 12.7635 - val_loss: 44.9763
# Epoch 309/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.7464 - val_loss: 45.1904
# Epoch 310/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.7494 - val_loss: 44.9188
# Epoch 311/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.7418 - val_loss: 44.7194
# Epoch 312/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 12.7338 - val_loss: 44.6888
# Epoch 313/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.7333 - val_loss: 44.7449
# Epoch 314/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 12.7273 - val_loss: 44.8408
# Epoch 315/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 12.7130 - val_loss: 45.0022
# Epoch 316/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 12.7159 - val_loss: 45.1761
# Epoch 317/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.7118 - val_loss: 44.9417
# Epoch 318/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.6978 - val_loss: 44.7097
# Epoch 319/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.6991 - val_loss: 44.9508
# Epoch 320/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 12.6961 - val_loss: 45.1296
# Epoch 321/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.6898 - val_loss: 45.1813
# Epoch 322/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.6887 - val_loss: 45.1403
# Epoch 323/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.6824 - val_loss: 45.0846
# Epoch 324/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 12.6722 - val_loss: 45.0045
# Epoch 325/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 12.6642 - val_loss: 44.4243
# Epoch 326/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 12.6794 - val_loss: 44.4588
# Epoch 327/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 12.6714 - val_loss: 45.0497
# Epoch 328/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 12.6522 - val_loss: 45.5479
# Epoch 329/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.6599 - val_loss: 45.3147
# Epoch 330/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 12.6475 - val_loss: 44.9279
# Epoch 331/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 12.6430 - val_loss: 44.6119
# Epoch 332/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 12.6400 - val_loss: 44.5811
# Epoch 333/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.6341 - val_loss: 45.1226
# Epoch 334/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 12.6232 - val_loss: 45.5408
# Epoch 335/1000
# 1/1 [==============================] - 0s 51ms/step - loss: 12.6229 - val_loss: 45.1943
# Epoch 336/1000
# 1/1 [==============================] - 0s 50ms/step - loss: 12.6143 - val_loss: 44.8088
# Epoch 337/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 12.6106 - val_loss: 44.9509
# Epoch 338/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.6009 - val_loss: 45.0631
# Epoch 339/1000
# 1/1 [==============================] - 0s 44ms/step - loss: 12.5979 - val_loss: 45.0635
# Epoch 340/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5916 - val_loss: 44.9819
# Epoch 341/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5896 - val_loss: 44.4901
# Epoch 342/1000
# 1/1 [==============================] - 0s 32ms/step - loss: 12.5876 - val_loss: 44.6817
# Epoch 343/1000
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5739 - val_loss: 44.9828
# Epoch 344/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5722 - val_loss: 45.1501
# Epoch 345/1000
# 1/1 [==============================] - 0s 40ms/step - loss: 12.5690 - val_loss: 44.6951
# Epoch 346/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5659 - val_loss: 44.7438
# Epoch 347/1000
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5547 - val_loss: 44.8828
# Epoch 348/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 12.5513 - val_loss: 45.0297
# Epoch 349/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 12.5446 - val_loss: 45.1593
# Epoch 350/1000
# 1/1 [==============================] - 0s 38ms/step - loss: 12.5387 - val_loss: 45.1870
# Epoch 351/1000
# 1/1 [==============================] - 0s 47ms/step - loss: 12.5350 - val_loss: 44.7204
# Epoch 352/1000
# 1/1 [==============================] - 0s 37ms/step - loss: 12.5426 - val_loss: 44.7645
# Epoch 353/1000
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5311 - val_loss: 45.3269
# Epoch 354/1000
# 1/1 [==============================] - 0s 39ms/step - loss: 12.5175 - val_loss: 45.6142
# Epoch 355/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.5310 - val_loss: 45.0441
# Epoch 356/1000
# 1/1 [==============================] - 0s 67ms/step - loss: 12.5117 - val_loss: 44.4662
# Epoch 357/1000
# 1/1 [==============================] - 0s 62ms/step - loss: 12.5081 - val_loss: 44.1949
# Epoch 358/1000
# 1/1 [==============================] - 0s 64ms/step - loss: 12.5114 - val_loss: 44.6918
# Epoch 359/1000
# 1/1 [==============================] - 0s 54ms/step - loss: 12.4938 - val_loss: 45.2141
# Epoch 360/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 12.4869 - val_loss: 45.5121
# Epoch 361/1000
# 1/1 [==============================] - 0s 72ms/step - loss: 12.4869 - val_loss: 45.0514
# Epoch 362/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.4787 - val_loss: 45.0637
# Epoch 363/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 12.4720 - val_loss: 45.0149
# Epoch 364/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.4636 - val_loss: 44.9456
# Epoch 365/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.4601 - val_loss: 44.8312
# Epoch 366/1000
# 1/1 [==============================] - 0s 87ms/step - loss: 12.4559 - val_loss: 45.1519
# Epoch 367/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 12.4467 - val_loss: 45.2699
# Epoch 368/1000
# 1/1 [==============================] - 0s 43ms/step - loss: 12.4479 - val_loss: 44.6624
# Epoch 369/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.4428 - val_loss: 44.6952
# Epoch 370/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.4297 - val_loss: 44.8685
# Epoch 371/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 12.4292 - val_loss: 45.0321
# Epoch 372/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.4170 - val_loss: 45.0737
# Epoch 373/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 12.4112 - val_loss: 44.6539
# Epoch 374/1000
# 1/1 [==============================] - 0s 77ms/step - loss: 12.4216 - val_loss: 44.8480
# Epoch 375/1000
# 1/1 [==============================] - 0s 57ms/step - loss: 12.4052 - val_loss: 45.4896
# Epoch 376/1000
# 1/1 [==============================] - 0s 59ms/step - loss: 12.4116 - val_loss: 45.1241
# Epoch 377/1000
# 1/1 [==============================] - 0s 68ms/step - loss: 12.3961 - val_loss: 44.6871
# Epoch 378/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 12.3963 - val_loss: 44.5405
# Epoch 379/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.3903 - val_loss: 44.6253
# Epoch 380/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 12.3797 - val_loss: 45.2377
# Epoch 381/1000
# 1/1 [==============================] - 0s 41ms/step - loss: 12.3810 - val_loss: 45.5760
# Epoch 382/1000
# 1/1 [==============================] - 0s 49ms/step - loss: 12.3685 - val_loss: 45.4699
# Epoch 383/1000
# 1/1 [==============================] - 0s 84ms/step - loss: 12.3660 - val_loss: 44.6913
# Epoch 384/1000
# 1/1 [==============================] - 0s 56ms/step - loss: 12.3697 - val_loss: 44.6341
# Epoch 385/1000
# 1/1 [==============================] - 0s 45ms/step - loss: 12.3546 - val_loss: 45.1645
# Epoch 386/1000
# 1/1 [==============================] - 0s 42ms/step - loss: 12.3462 - val_loss: 45.4072
# Epoch 387/1000
# 1/1 [==============================] - 0s 63ms/step - loss: 12.3489 - val_loss: 44.6922
# Epoch 388/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 12.3348 - val_loss: 44.2815
# Epoch 389/1000
# 1/1 [==============================] - 0s 69ms/step - loss: 12.3396 - val_loss: 44.6880
# Epoch 390/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 12.3229 - val_loss: 45.1836
# Epoch 391/1000
# 1/1 [==============================] - 0s 65ms/step - loss: 12.3261 - val_loss: 45.3298
# Epoch 392/1000
# 1/1 [==============================] - 0s 66ms/step - loss: 12.3113 - val_loss: 45.1989
# Epoch 393/1000
# 1/1 [==============================] - 0s 53ms/step - loss: 12.3012 - val_loss: 44.5439
# Epoch 394/1000
# 1/1 [==============================] - 0s 58ms/step - loss: 12.3183 - val_loss: 44.6851
# Epoch 395/1000
# 1/1 [==============================] - 0s 75ms/step - loss: 12.3051 - val_loss: 45.4294
# Epoch 396/1000
# 1/1 [==============================] - 0s 46ms/step - loss: 12.2925 - val_loss: 45.2384
# Epoch 397/1000
# 1/1 [==============================] - ETA: 0s - loss: 12.2834

# %%
# RNN model
#if args.model == 'RNN':
# input for RNN
Mix_X_100Block = []
for i in range(len(DF)):
    if DF['Random/\nBlock'].iloc[i] == 'B':
        Sequency_X = []
        for j in range(int(DF['Ratio_1'].iloc[i])):
            Sequency_X.append((X_1.iloc[i].values))
        for j in range(int(DF['Ratio_2'].iloc[i])):
            Sequency_X.append((X_2.iloc[i].values))
    else:
        random.seed(10)
        X1_random_position = random.sample(range(0, 100), int(DF['Ratio_1'].iloc[i]))
        Sequency_X = [0 for a in range(100)]
        for j in range(100):
            if j in X1_random_position:
                Sequency_X[j] = list(X_1.iloc[i].values)
            else:
                Sequency_X[j] = list(X_2.iloc[i].values)
    Mix_X_100Block.append(Sequency_X)

Mix_X_100Block = np.array(Mix_X_100Block)

# data split into train/test sets
X_train, X_test, y_train, y_test = train_test_split(Mix_X_100Block, DF['Tg_avg'], test_size=0.2, random_state=11)

# model setup using the optimized architecture
LSTMunits = 20 # hyperprameter for LSTM
RNNmodel = Sequential()
RNNmodel.add(Bidirectional(LSTM(LSTMunits, return_sequences=True), input_shape=(100,125)))
RNNmodel.add(Bidirectional(LSTM(LSTMunits, return_sequences=True)))
RNNmodel.add(TimeDistributed(Dense(int(LSTMunits/2), activation="relu")))
RNNmodel.add(Reshape((int(LSTMunits/2*100),)))
RNNmodel.add(Dense(1))

RNNmodel.compile(loss='mse', optimizer='adam')
RNNmodel.fit(X_train, y_train, validation_split=0.2, epochs=200, batch_size=64)

filepath = 'PK_RNN.model'
save_model(model, filepath, save_format='h5')

# model evaluation
print("model performance")
y_pred_train = RNNmodel.predict((X_train))
print("Train set R^2: %.2f" % r2_score(y_train, y_pred_train))
print("Train MAE score: %.2f" % mean_absolute_error(y_train, y_pred_train))
print("Train RMSE score: %.2f" % np.sqrt(mean_squared_error(y_train, y_pred_train)))
y_pred_test = RNNmodel.predict((X_test))
print("Test set R^2: %.2f" % r2_score(y_test, y_pred_test))
print("Test MAE score: %.2f" % mean_absolute_error(y_test, y_pred_test))
print("Test RMSE score: %.2f" % np.sqrt(mean_squared_error(y_test, y_pred_test)))

# %%
if __name__ == '__main__':

    parser = argparse.ArgumentParser()
    parser.add_argument('--model', type=str, required = True,
    	help='Choose either "CNN", "DNN", "RNN", or "Fusion" for model architecture')

    parsed_args = parser.parse_args()

    train(parsed_args)
# Out:
# usage: colab_kernel_launcher.py [-h] --model MODEL
# colab_kernel_launcher.py: error: the following arguments are required: --model
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
